# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("VOTING_RESULTS.csv")

# %%
df.head()
# Out:
#        CANDIDATE_NAME  CONSTITUENCY_CODE            CONSTITUENCY_NAME  \
# 0         AYAN MANDAL                  1  ANDAMAN AND NICOBAR ISLANDS
# 1  KULDEEP RAI SHARMA                  1  ANDAMAN AND NICOBAR ISLANDS
# 2        PRAKASH MINJ                  1  ANDAMAN AND NICOBAR ISLANDS
# 3        VISHAL JOLLY                  1  ANDAMAN AND NICOBAR ISLANDS
# 4      SANJAY MESHACK                  1  ANDAMAN AND NICOBAR ISLANDS
#
#    EVM_VOTES                         PARTY  POSTAL VOTES STATE_CODE  \
# 0       1717  All India Trinamool Congress             4        U01
# 1      95249      Indian National Congress            59        U01
# 2       2478           Bahujan Samaj Party             8        U01
# 3      93772        Bharatiya Janata Party           129        U01
# 4       2837               Aam Aadmi Party             2        U01
#
#                     STATE_NAME  TOTAL_VOTES  VOTING_PERCENTAGE
# 0  ANDAMAN AND NICOBAR ISLANDS         1721               0.83
# ...

# %%
df.tail()
# Out:
#            CANDIDATE_NAME  CONSTITUENCY_CODE CONSTITUENCY_NAME  EVM_VOTES  \
# 8051        MINATI SARKAR                 26          ULUBERIA       1696
# 8052          SIMAL SAREN                 26          ULUBERIA       2338
# 8053          AMAL BARMAN                 26          ULUBERIA       1885
# 8054       DURGADAS HAJRA                 26          ULUBERIA       6770
# 8055  SUSANTA KUMAR DALUI                 26          ULUBERIA       3077
#
#                                             PARTY  POSTAL VOTES STATE_CODE  \
# 8051  SOCIALIST UNITY CENTRE OF INDIA (COMMUNIST)             1        S25
# 8052                          Indian Unity Centre             1        S25
# 8053                                  Independent             0        S25
# 8054                                  Independent             0        S25
# 8055                                  Independent             0        S25
#
#        STATE_NAME  TOTAL_VOTES  VOTING_PERCENTAGE
# ...

# %%
X = df['CANDIDATE_NAME']
Y = df['EVM_VOTES']

# %%
plt.bar(X,Y)    
plt.xlabel('candidate name', fontsize=5)
plt.ylabel('number of votes', fontsize=5)
plt.xticks(index, label, fontsize=5)
plt.title('CANDIDATE_NAME vs EVM_VOTES')
plt.show()
